# %%
# suppress warnings
# %pip install stata_setup --quiet
import stata_setup
import sys
sys.path.append(r'C:/Program Files/Stata17/utilities')
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pystata import config
config.init('mp')
# Out:
#   ___  ____  ____  ____  ____ ©
#  /__    /   ____/   /   ____/      17.0
# ___/   /   /___/   /   /___/       MP—Parallel Edition
#
#  Statistics and Data Science       Copyright 1985-2021 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-STATA-PC        https://www.stata.com
#                                    979-696-4600        stata@stata.com
#
# Stata license: Unlimited-user 4-core network, expiring 31 May 2023
# Serial number: 501709320052
#   Licensed to: IFPRI
#                IFPRI
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. More than 2 billion observations are allowed; see help obs_advice.
#       3. Maximum number of variables is set to 5,000; see help set_maxvar.

# %%
import pandas as pd
# read csv file in utf-8 format
df = pd.read_csv(r'C:\Users\WeilunShi\Dropbox (IFPRI)\CML-Ethiopia - team folder\CML_50_Towns_Results\CML_Agg_merged.csv', encoding='utf-8')

# %%
frequency = pd.Series(df['intensity']).value_counts()
percentage = (frequency / df['intensity'].size) * 100

print(percentage)
# Out:
# intensity
# 2.0    16.863507
# 1.0    15.368515
# 3.0     4.634475
# 4.0     1.166094
# Name: count, dtype: float64

# %%
41.44/(52.07+41.44)
# Out:
# 0.4431611592343065

# %%
import datetime

# convert date to datetime format
df['date'] = pd.to_datetime(df['date'])

# convert time_receive and time_sent to datetime format
df['time_receive'] = pd.to_datetime(df['time_receive'])
df['time_sent'] = pd.to_datetime(df['time_sent'])

# see the average time difference between time_receive and time_send
df['time_diff'] = df['time_receive'] - df['time_sent']
df['time_diff'].mean()
# Out:
# C:\Users\WeilunShi\AppData\Local\Temp\ipykernel_36720\358579119.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['time_sent'] = pd.to_datetime(df['time_sent'])
# Timedelta('0 days 00:25:58.555837942')

# %%
# average time of time_sent
df['time_sent'].median()
# Out:
# Timestamp('2023-05-01 15:35:00')

# %%
# read dta file
fb = pd.read_stata(r'C:\Users\WeilunShi\Dropbox (IFPRI)\CML-Ethiopia - team folder\CML_50_Towns_Results\Feedback_survey_data\CML  Feedback Survey.dta')

# %%
frequency = pd.Series(fb['d1']).value_counts()
percentage = (frequency / fb['d1'].size) * 100

print(percentage)
# Out:
# d1
# 50-80%    42.396777
# 30-50%    25.075529
# >80%      17.522659
# 10-30%    12.688822
# <10%       2.316213
# Name: count, dtype: float64

# %%
# Split the multiple-choice values
split_choices = fb['d4'].str.split(' ')

# Flatten the resulting lists
flat_choices = [choice for sublist in split_choices for choice in sublist]

# Count the frequency of each choice
frequency = pd.Series(flat_choices).value_counts()

# Calculate the percentage
percentage = (frequency / len(flat_choices)) * 100

print(percentage)
# Out:
# 8    31.020408
# 2    23.333333
# 4    20.340136
# 5     9.251701
# 1     8.503401
# 3     6.666667
# 6     0.544218
# 7     0.340136
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d4_1']).value_counts()
percentage = (frequency / fb['d4_1'].size) * 100

print(percentage)
# Out:
# d4_1
# 0    87.411883
# 1    12.588117
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d5']).value_counts()
percentage = (frequency / fb['d5'].size) * 100

print(percentage)
# Out:
# d5
# Yes    95.971803
# No      4.028197
# Name: count, dtype: float64

# %%
# Split the multiple-choice values
split_choices = fb['d5_1'].str.split(' ')

# Flatten the resulting lists
flat_choices = [choice for sublist in split_choices for choice in sublist]

# Count the frequency of each choice
frequency = pd.Series(flat_choices).value_counts()

# Calculate the percentage
percentage = (frequency / len(flat_choices)) * 100

print(percentage/(100-95.682731)*100)
# Out:
#      2216.279109
# 1      48.837210
# 5      18.604651
# 2      11.627907
# 4      11.627907
# 3       9.302326
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d6']).value_counts()
percentage = (frequency / fb['d6'].size) * 100

print(percentage)
# Out:
# d6
# No     68.479355
# Yes    31.520645
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d7_3']).value_counts()
percentage = (frequency / fb['d7_3'].size) * 100

print(percentage/(30.412890+5.941591)*100)
# Out:
# d7_3
# No     83.656511
# Yes    16.343490
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d7_1']).value_counts()
percentage = (frequency / fb['d7_1'].size) * 100

print(percentage)
# Out:
# d7_1
# No     84.793555
# Yes    15.206445
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d8']).value_counts()
percentage = (frequency / fb['d8'].size) * 100

print(percentage)
# Out:
# d8
# No     68.076536
# Yes    31.923464
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d7_2']).value_counts()
percentage = (frequency / fb['d7_2'].size) * 100

print(percentage)
# Out:
# d7_2
# No     67.472306
# Yes    32.527694
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d8']).value_counts()
percentage = (frequency / fb['d8'].size) * 100

print(percentage)
# Out:
# d8
# No     68.076536
# Yes    31.923464
# Name: count, dtype: float64

# %%
frequency = pd.Series(fb['d9']).value_counts()
percentage = (frequency / fb['d9'].size) * 100

print(percentage)
# Out:
# d9
# Yes    97.985901
# No      2.014099
# Name: count, dtype: float64

# %%
df=df[['receiver_id','Longitude','Latitude','POINT_X','POINT_Y']]

# %%
# plot the map
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point, Polygon
import contextily as ctx
boundaries = gpd.read_file(r"C:\Users\WeilunShi\Dropbox (IFPRI)\CML-Ethiopia - team folder\CML_50_Towns_Results\eth_adm_csa_bofedb_2021_shp\eth_admbndl_admALL_csa_bofedb_itos_2021.shp")
# create a geometry column from coordinates
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]

# Coordinate reference system : WGS84
crs = {'init': 'epsg:4326'}

# create GeoDataFrame
geo_df = gpd.GeoDataFrame(df,
    crs = crs,
    geometry = geometry)

# plot the map
fig, ax = plt.subplots(figsize = (15,15))
boundaries.plot(ax=ax, alpha=0, color='grey')
geo_df.plot(ax=ax, markersize=15, color='red', marker='x', label='grid')
plt.legend(prop={'size':15})
ctx.add_basemap(ax, crs=geo_df.crs.to_string(), source=ctx.providers.Stamen.TonerLite)
plt.title('CML Locations in Ethiopia', fontsize=20)
plt.xlabel('Longitude', fontsize=15)
plt.ylabel('Latitude', fontsize=15)

# add points POINT_X and POINT_Y
geo_df2 = gpd.GeoDataFrame(df,
    crs = crs,
    geometry = [Point(xy) for xy in zip(df['POINT_X'], df['POINT_Y'])])
geo_df2.plot(ax=ax, markersize=15, color='blue', marker='o', label='individual')
plt.legend(prop={'size':15})

# zoom in
ax.set_xlim(32.5, 45)
ax.set_ylim(4, 13)




plt.show()
# Out:
# c:\Users\WeilunShi\Dropbox (IFPRI)\CML-Ethiopia - team folder\CML_50_Towns_Results\.venv\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# c:\Users\WeilunShi\Dropbox (IFPRI)\CML-Ethiopia - team folder\CML_50_Towns_Results\.venv\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
